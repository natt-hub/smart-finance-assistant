# %% [markdown]
# <a href="https://colab.research.google.com/github/natt-hub/smart-finance-assistant/blob/main/smart_finance_assistant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load dataset
df = pd.read_csv('transactions.csv')

# Clean Amount column
df['Amount'] = pd.to_numeric(df['Amount'].str.replace('$', ''), errors='coerce')

# Drop invalid values
df = df.dropna(subset=['Amount'])

# Basic analysis
total_spent = df['Amount'].sum()
average_spent = df['Amount'].mean()

# Group by category
category_summary = df.groupby('Category')['Amount'].sum().sort_values(ascending=False)

print("📊 SMART FINANCE SUMMARY")
print("=" * 40)
print(f"Total Spending: ${total_spent:.2f}")
print(f"Average Transaction: ${average_spent:.2f}")

print("\n💰 Spending by Category:")
for category, amount in category_summary.items():
    print(f"{category}: ${amount:.2f}")
# Out:
# 📊 SMART FINANCE SUMMARY
# ...
# Total Spending: $873.30
# Average Transaction: $43.66
#
# 💰 Spending by Category:
# Groceries: $394.70
# Entertainment: $206.95
# Dining: $113.90
# Transport: $89.50
# Utilities: $67.80
# Coffee: $37.95
# Refund: $-37.50
